# %%
# %load_ext autoreload
# %autoreload 2
from src.train import train
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
train(['--no-validate', '--epochs', '1000', '--plot', '--batch-size', '2'])
# Out:
# Mode.TRAIN:   0%|                                                                                 | 0/2 [00:00<?, ?it/s]
# Epoch [1/1000]
# torch.Size([2, 1, 256, 256])
# torch.Size([2, 65536])
# 0.0031339633278548717
# Mode.TRAIN:  50%|████████████████████████████████████▌                                    | 1/2 [00:00<00:00,  1.22it/s]
# torch.Size([2, 1, 256, 256])
# torch.Size([2, 65536])
# torch.Size([2, 1, 256, 256])
# torch.Size([2, 65536])
# 7.869313412811607e-05
# Mode.TRAIN: 100%|█████████████████████████████████████████████████████████████████████████| 2/2 [00:01<00:00,  1.20it/s]
# torch.Size([2, 1, 256, 256])
# torch.Size([2, 65536])
# Mode.TRAIN Loss: 0.3768 IoU: 0.0004 Dice: 0.0008
# Saving checkpoint...
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# <ipython-input-9-54a1ac71b163> in <module>
# ...
